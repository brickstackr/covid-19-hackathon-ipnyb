# %%
#### The original source for this data is the Google Map I created of social media about grocery shortages
#### Resulting from the COVID-19 pandemic. 
#### URL: https://www.google.com/maps/d/viewer?mid=1Omne_joZQaoc5mLxZndIPUDWX172WJOr&hl=en&usp=sharing 
### The first chart maps the shortages geographically, the second chart shows which types of items were the most in demand.
import plotly.graph_objects as go
import pandas as pd
import plotly.express as px
import folium

# %%
m = folium.Map(
   location=[48, -102],
    zoom_start=3,
    tiles='OpenStreetMap'
)
#### The original source for this data is the Google Map I created of social media about grocery shortages
#### Resulting from the COVID-19 pandemic. 
#### URL: https://www.google.com/maps/d/viewer?mid=1Omne_joZQaoc5mLxZndIPUDWX172WJOr&hl=en&usp=sharing 
### The first chart maps the shortages geographically, the second chart shows which types of items were the most in demand.

# tooltip = 'Click me!'

# the lat long data has to be copied from the source on google maps 

#start of food data 
folium.Marker([21, -157], popup='Canned Meat, 2/26/20').add_to(m)
folium.Marker([38.80601, -77.17532], popup='Pasta, 2/28/20').add_to(m)
folium.Marker([37.80601, -122.17532], popup='Fresh Fruit, 3/2/2020').add_to(m)
folium.Marker([37.80601, -122.40], popup='Ramen, 3/11/2020').add_to(m)
folium.Marker([41.738, -111.836], popup='Grocery staples, 3/11/2020').add_to(m)
folium.Marker([37.700, -122.400], popup='Flour, 3/12/2020').add_to(m)
folium.Marker([43.070, -89.410], popup='Beer, 3/12/2020').add_to(m)
folium.Marker([40.716, -74.012], popup='Canned Goods, 3/12/2020').add_to(m)
folium.Marker([40.715, -73.9], popup='Pasta, 3/12/2020').add_to(m)
folium.Marker([38.903, -77.027], popup='Grocery staples, 3/12/2020').add_to(m)
folium.Marker([38.750, -77.065], popup='Eggs, 3/12/2020').add_to(m)
folium.Marker([38.906, -77.038], popup='Eggs Unavailable, 3/12/2020').add_to(m)
folium.Marker([38.912, -77.031], popup='Grocery staples, 3/12/2020').add_to(m)
folium.Marker([44.962, -93.311], popup='Canned soup, 3/12/2020').add_to(m)
folium.Marker([45.125, -93.212], popup='Meat, 3/12/2020').add_to(m)
folium.Marker([45.055, -93.486], popup='Pasta, 3/12/2020').add_to(m)
folium.Marker([45.001, -93.036], popup='Bread, 3/12/2020').add_to(m)
folium.Marker([44.946, -93.190], popup='Fresh Fruit, 3/12/2020').add_to(m)
folium.Marker([44.900, -93.212], popup='Grocery staples, 3/12/2020').add_to(m)
folium.Marker([41.858, -87.627], popup='Ice cream, 3/12/2020').add_to(m)
folium.Marker([40.791, -73.937], popup='Grocery staples, 3/12/2020').add_to(m)
folium.Marker([40.699, -74.220], popup='Pasta, 3/12/2020').add_to(m)
folium.Marker([40.864, -74.063], popup='Bread, 3/12/2020').add_to(m)
folium.Marker([42.280, -71.157], popup='Meat, 3/12/2020').add_to(m)
folium.Marker([38.903, -77.027], popup='Meat, 3/12/2020').add_to(m)
folium.Marker([38.880, -77.000], popup='Cereal, 3/12/2020').add_to(m)
folium.Marker([34.038, -118.239], popup='Fresh fruit, 3/12/2020').add_to(m)
folium.Marker([34.030, -118.230], popup='Grocery staples, 3/12/2020').add_to(m)
folium.Marker([34.038, -118.239], popup='Meat, 3/12/2020').add_to(m)
folium.Marker([34.141, -118.387], popup='Grocery staples, 3/12/2020').add_to(m)
folium.Marker([34.139, -118.387], popup='Meat, 3/12/2020').add_to(m)
folium.Marker([34.141, -118.386], popup='Pasta, 3/12/2020').add_to(m)
folium.Marker([34.141, -118.386], popup='Pasta, 3/12/2020').add_to(m)
folium.Marker([34.140, -118.389], popup='Grocery staples unavailable, 3/12/2020').add_to(m)
folium.Marker([34.049, -118.256], popup='Grocery staples unavailable, 3/12/2020').add_to(m)
folium.Marker([40.721, -73.808], popup='Grocery staples, 3/12/2020').add_to(m)
folium.Marker([40.729, -73.789], popup='Fresh vegetables, 3/12/2020').add_to(m)
folium.Marker([40.721, -73.807], popup='Meat, 3/12/2020').add_to(m)
folium.Marker([40.729, -73.789], popup='Grocery staples, 3/12/2020').add_to(m)
folium.Marker([34.146, -118.146], popup='Pasta, 3/12/2020').add_to(m)
folium.Marker([34.147, -118.141], popup='Canned goods, 3/12/2020').add_to(m)
folium.Marker([34.146, -118.146], popup='Frozen food, 3/12/2020').add_to(m)
folium.Marker([43.068, -89.420], popup='Wine, 3/12/2020').add_to(m)
folium.Marker([40.017, -105.252], popup='Rice, 3/12/2020').add_to(m)
folium.Marker([40.017, -105.252], popup='Grocery staples, 3/12/2020').add_to(m)
folium.Marker([40.017, -105.352], popup='Frozen food, 3/12/2020').add_to(m)
folium.Marker([33.492, -111.937], popup='Frozen food, 3/12/2020').add_to(m)
folium.Marker([33.486, -111.910], popup='Pasta, 3/12/2020').add_to(m)
folium.Marker([38.882, -77.114], popup='Frozen food, 3/12/2020').add_to(m)
folium.Marker([38.888, -77.112], popup='Canned soup, 3/12/2020').add_to(m)
folium.Marker([38.882, -77.100], popup='Meat, 3/12/2020').add_to(m)
folium.Marker([38.900, -77.100], popup='Fresh Fruit, 3/12/2020').add_to(m)
folium.Marker([38.107, -77.106], popup='Fresh Vegetables, 3/12/2020').add_to(m)
folium.Marker([38.885, -77.101], popup='Meat, 3/12/2020').add_to(m)
folium.Marker([38.885, -77.101], popup='Meat, 3/12/2020').add_to(m)
folium.Marker([33.916, -118.353], popup='Grocery staples- unavailable, 3/13/2020').add_to(m)
folium.Marker([42.884, -78.880], popup='Grocery staples- unavailable, 3/13/2020').add_to(m)
folium.Marker([38.955, -77.421], popup='Pasta, 3/17/2020').add_to(m)
folium.Marker([37.777, -122.421], popup='Eggs, 3/18/2020').add_to(m)
folium.Marker([39.932, -82.983], popup='Pasta, 3/18/2020').add_to(m)
folium.Marker([40.078, -82.951], popup='Meat- unavailable, 3/18/2020').add_to(m)
folium.Marker([39.712, -83.114], popup='Canned goods, 3/18/2020').add_to(m)
folium.Marker([34.021, -118.398], popup='Bread- unavailable, 3/18/2020').add_to(m)
folium.Marker([37.700, -122.448], popup='Eggs- unavailable, 3/19/2020').add_to(m)
folium.Marker([49.283, -123.121], popup='Canned goods, 3/23/2020').add_to(m)
folium.Marker([33.535, -112.193], popup='Flour- unavailable, 3/23/2020').add_to(m)
folium.Marker([32.247, -110.992], popup='Pasta, 3/29/2020').add_to(m)
folium.Marker([53.546, -113.501], popup='Flour, 4/6/2020').add_to(m)
folium.Marker([53.552, -113.534], popup='Yeast, 4/6/2020').add_to(m)
folium.Marker([40.699, -74.227], popup='Fresh fruit, 4/9/2020').add_to(m)
folium.Marker([40.720, -74.226], popup='Fresh vegetables, 4/9/2020').add_to(m)
folium.Marker([40.698, -74.227], popup='Flour- unavailable, 4/11/2020').add_to(m)
folium.Marker([38.812, -77.440], popup='Frozen food, 4/11/2020').add_to(m)
folium.Marker([35.866, -111.749], popup='Pasta- unavaliable, 4/15/2020').add_to(m)
folium.Marker([41.749, -88.152], popup='Meat- unavailable, 5/4/2020').add_to(m)

#start of paper and plastics data

folium.Marker([38.903, -77.027], popup='Sanitizing wipes, 3/2/2020').add_to(m)
folium.Marker([40.064, -74.063], popup='Paper towels, 3/5/2020').add_to(m)
folium.Marker([38.950, -77.360], popup='Toilet paper, 3/9/2020').add_to(m)
folium.Marker([38.955, -77.365], popup='Paper towels, 3/9/2020').add_to(m)
folium.Marker([33.448, -112.084], popup='Toilet paper- unavailable, 3/11/2020').add_to(m)
folium.Marker([47.905, -97.057], popup='Toilet paper- unavailable, 3/11/2020').add_to(m)
folium.Marker([41.738, -111.836], popup='Toilet paper, 3/11/2020').add_to(m)
folium.Marker([43.577, -116.189], popup='Toilet paper, 3/11/2020').add_to(m)
folium.Marker([37.328, -121.889], popup='Toilet paper, 3/12/2020').add_to(m)
folium.Marker([38.966, -77.065], popup='Toilet paper, 3/12/2020').add_to(m)
folium.Marker([28.538, -81.397], popup='Toilet paper, 3/12/2020').add_to(m)
folium.Marker([28.549, -81.303], popup='Paper towels, 3/12/2020').add_to(m)
folium.Marker([44.962, -93.311], popup='Toilet paper, 3/12/2020').add_to(m)
folium.Marker([44.962, -93.311], popup='Toilet paper, 3/12/2020').add_to(m)
folium.Marker([34.559, -111.868], popup='Toilet paper, 3/12/2020').add_to(m)
folium.Marker([40.716, -74.012], popup='Toilet paper, 3/12/2020').add_to(m)
folium.Marker([40.800, -74.0150], popup='Toilet paper, 3/12/2020').add_to(m)
folium.Marker([40.800, -74.0150], popup='Paper towels, 3/12/2020').add_to(m)
folium.Marker([34.139, -118.387], popup='Toilet paper, 3/12/2020').add_to(m)
folium.Marker([38.955, -77.421], popup='Toilet paper- unavailable, 3/17/2020').add_to(m)
folium.Marker([37.773, -122.416], popup='Toilet paper- unavailable, 3/18/2020').add_to(m)
folium.Marker([38.903, -77.028], popup='Toilet paper- unavailable, 3/23/2020').add_to(m)
folium.Marker([49.283, -123.122], popup='Toilet paper, 3/23/2020').add_to(m)
folium.Marker([40.848, -74.574], popup='Toilet paper- unavailable, 3/23/2020').add_to(m)
folium.Marker([53.546, -113.501], popup='Toilet paper- unavailable, 3/23/2020').add_to(m)
folium.Marker([38.847, -77.313], popup='Toilet paper- unavailable, 3/23/2020').add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;"></iframe></div></div>

# %%
# Out:
# <div>
#
#
#             <div id="e1e5617f-587a-445c-857d-8f42efb51011" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("e1e5617f-587a-445c-857d-8f42efb51011")) {
#                     Plotly.newPlot(
#                         'e1e5617f-587a-445c-857d-8f42efb51011',
# ...
